# %%
import pandas as pd
from pprint import pprint


ref = pd.read_csv("/Users/nident/Desktop/JOB/Cancer Cell Line Encyclopedia (CCLE)/data/pilot/KRAS_data_expanded.csv")
pprint(ref.columns)
ref.head(2)
# Out:
# Index(['ModelID', 'KRAS_GeneEffect', 'KRAS_expression', 'KRAS_protein_changes',
#        'KRAS_hotspot', 'PatientID', 'CellLineName', 'PrimaryOrMetastasis',
#        'SampleCollectionSite', 'Age', 'Sex', 'GrowthPattern'],
#       dtype='str')
#       ModelID  KRAS_GeneEffect  KRAS_expression KRAS_protein_changes  \
# 0  ACH-000552        -0.468224         4.958708                  NaN
# 1  ACH-000958        -0.526112         4.672029                  NaN
#
#    KRAS_hotspot  PatientID CellLineName PrimaryOrMetastasis  \
# 0             0  PT-sF39aT        HT-29             Primary
# 1             0  PT-EB6qeM         SW48             Primary
#
#   SampleCollectionSite   Age     Sex GrowthPattern
# 0      large_intestine  44.0  Female      Adherent
# 1                Colon  83.0  Female         Mixed
